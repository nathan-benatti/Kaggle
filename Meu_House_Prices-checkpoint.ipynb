# %% [markdown]
# # House Prices Challange

# %% [markdown]
#   First i want to thanks Ken Jee (https://www.youtube.com/watch?v=8igH8qZafpo&t=172s) for recommending this kaggle competition for my beginning  in Data Science learning.
#
#   I will try to explain every step i make here, but how i am just a beginner i may be mistaken about a lot of my assumptions, so PLEASE CORRECT ME if you can.

# %% [markdown]
# ## Importing Librarys

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import scipy.stats as st

# %% [markdown]
# ## Data Visualization

# %%
#Reading data
train = pd.read_csv(r'C:\Users\Nathan\Documents\House Prices\house-prices-advanced-regression-techniques\train.csv')
test = pd.read_csv(r'C:\Users\Nathan\Documents\House Prices\house-prices-advanced-regression-techniques\test.csv')

# %%
train.head() # Checkin 5 rows of Train Dataframe
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train['SalePrice'].describe() # checking some useful info of our target variable, just to get a hang of it
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
train.shape # Checking Shape
# Out:
# (1460, 81)

# %%
test.shape
# Out:
# (1459, 80)

# %% [markdown]
#  test dataframe has 1 less column than train set, and that's cause test don't have SalePrice column

# %% [markdown]
# ## Univariate Analysis

# %%
import scipy.stats as st
y = train['SalePrice']
sb.distplot(y)

# %% [markdown]
#  Looking at the distribution of Saleprices, it becomes obvious that it is not a normal (gaussian) distribution, cause it's visible it had a positive skewness, but anyway i will do some normality check just for demonstration, and check skewness and kurtosis coeficients values

# %%
test_normality = lambda x: st.shapiro(x.fillna(0))[1] < 0.01 # testing normality for 1% of significance
normal = pd.DataFrame(train['SalePrice'])
normal = normal.apply(test_normality)
print(not normal.any())
# Out:
# False

# %%
print('Skewness : %f'% train['SalePrice'].skew())
print('Kurtosis : %f'% train['SalePrice'].kurt())
# Out:
# Skewness : 1.882876
# Kurtosis : 6.536282

# %% [markdown]
#  Later, we will model our data for prediction purpose, for that it is interessing transforming our target variable distribution to match closer to a normal distribution, cause this modellings algorythms work better with them, then later we can inverse the transformation to get the real values again
#
#  There is many ways to transform de distribution to get a normal shape, i will use a simple  natural log (ln) transformation for that

# %%
# log transformation
SalePricelog = np.log(train['SalePrice'])
# getting new skewness and kurtosis values
print('Skewness : %f'% SalePricelog.skew())
print('Kurtosis : %f'% SalePricelog.kurt())
# Out:
# Skewness : 0.121335
# Kurtosis : 0.809532

# %%
sb.distplot(SalePricelog)

# %% [markdown]
#  But transforming and plotting just for visualization for now, we will use this later

# %% [markdown]
# ## Multivariable Analysis
#
# So, we already had a pretty good look on our target variable (SalePrice), now we will try to get some info about the relations, or do i mean, correlations between all other variables
#
# For that i will use seaborn heatmap, and search for those bright/warm squares , which are those with higher correlation coeficient (I will be using the default Pearson correlation method)

# %%
corr = train.corr()
plt.subplots(figsize=(50,20))
sb.heatmap(corr,vmax=.9,square=True,annot=True)

# %% [markdown]
# Okay, so here we can find some correlations that can be meaningful here, like 'YearBuilt' is highly correlated with 'GarageYrBlt'(Garage Year Built) which may say that the Garage Year Built is not that relevant  because of the GARAGE year built but beacause of the year built in general ?
#
# And 'GrLivArea' with 'TotRomAbvGrd' (TotalRoomsAboveGround), of course if the ground live area of the house is bigger, chances are that are more rooms in it, so makes perfectly sense.
#
# 'GarageCars' and 'GarageArea'. Of course if the GarageArea is bigger it can fit more cars in it, Some of this features maybe can be dispensable because of the redundant quality of them, but for now i will leave them be.
#
#
# THE MOST IMPORTANT ROW !
#  Let's get a quick look on the most important row, the correlation row of the SalePrice.

# %%
Num=corr['SalePrice'].sort_values(ascending=False).head(20).to_frame()
Num = Num.drop(['SalePrice'])
Num
# Out:
#               SalePrice
# OverallQual    0.790982
# GrLivArea      0.708624
# GarageCars     0.640409
# GarageArea     0.623431
# TotalBsmtSF    0.613581
# 1stFlrSF       0.605852
# FullBath       0.560664
# TotRmsAbvGrd   0.533723
# YearBuilt      0.522897
# YearRemodAdd   0.507101
# GarageYrBlt    0.486362
# MasVnrArea     0.477493
# Fireplaces     0.466929
# BsmtFinSF1     0.386420
# LotFrontage    0.351799
# WoodDeckSF     0.324413
# 2ndFlrSF       0.319334
# OpenPorchSF    0.315856
# HalfBath       0.284108

# %% [markdown]
# It amazes me when data break our expectations.
#
# It makes perfect sense to me GroundLiveArea had such a important impact on SalePrices, but i confess i wasn't exepcting OverAllQuality would have the higher coeficient.
# Other funny thing, i thought LotFrontage would be one of the most important features, but hygiene is shurely more important, because a FULLBATH is way more relevant to a house price.

# %% [markdown]
# ## Missing Data Treatment
#
# We will check for missing data on features, the infamous NaN values, and see what we will do with them

# %%
# Checking for missing values and sorting values in descending order
sb.set_style("whitegrid")
missing_train = train.isnull().sum()
missing_train = missing_train[missing_train>0]
missing_train.sort_values(ascending=False,inplace=True)
missing_train.plot.bar(figsize=(12,5))

# %%
# comparing missing data with, the missing data/number_of_samples coeficient
percent = (train.isnull().sum()/train.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([missing_train,percent],axis=1,keys=['Missing','Percent'])
missing_data.head(20)
# Out:
#               Missing   Percent
# PoolQC         1453.0  0.995205
# MiscFeature    1406.0  0.963014
# Alley          1369.0  0.937671
# Fence          1179.0  0.807534
# FireplaceQu     690.0  0.472603
# LotFrontage     259.0  0.177397
# GarageYrBlt      81.0  0.055479
# GarageType       81.0  0.055479
# GarageFinish     81.0  0.055479
# GarageQual       81.0  0.055479
# GarageCond       81.0  0.055479
# BsmtFinType2     38.0  0.026027
# BsmtExposure     38.0  0.026027
# BsmtFinType1     37.0  0.025342
# BsmtCond         37.0  0.025342
# BsmtQual         37.0  0.025342
# MasVnrArea        8.0  0.005479
# MasVnrType        8.0  0.005479
# Electrical        1.0  0.000685
# Utilities         NaN  0.000000

# %%
# comparing missing data with, the missing data/number_of_samples coeficient, for test dataset
missing_test = test.isnull().sum()
missing_test = missing_test[missing_test>0]
percent = (test.isnull().sum()/test.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([missing_test,percent],axis=1,keys=['Missing','Percent'])
missing_data.head(40)
# Out:
#               Missing   Percent
# MSZoning          4.0  0.002742
# LotFrontage     227.0  0.155586
# Alley          1352.0  0.926662
# Utilities         2.0  0.001371
# Exterior1st       1.0  0.000685
# Exterior2nd       1.0  0.000685
# MasVnrType       16.0  0.010966
# MasVnrArea       15.0  0.010281
# BsmtQual         44.0  0.030158
# BsmtCond         45.0  0.030843
# BsmtExposure     44.0  0.030158
# BsmtFinType1     42.0  0.028787
# BsmtFinSF1        1.0  0.000685
# BsmtFinType2     42.0  0.028787
# BsmtFinSF2        1.0  0.000685
# BsmtUnfSF         1.0  0.000685
# TotalBsmtSF       1.0  0.000685
# BsmtFullBath      2.0  0.001371
# BsmtHalfBath      2.0  0.001371
# KitchenQual       1.0  0.000685
# Functional        2.0  0.001371
# FireplaceQu     730.0  0.500343
# GarageType       76.0  0.052090
# GarageYrBlt      78.0  0.053461
# GarageFinish     78.0  0.053461
# GarageCars        1.0  0.000685
# GarageArea        1.0  0.000685
# GarageQual       78.0  0.053461
# ...

# %% [markdown]
# We are sure missing a lot of pools here, maybe because pools are just for some rich bastards !! But, being serious now, i will adopt the convenience that if we are missing more than 15% of the feature data, we will drop it, cause we can't have much use of it.

# %%
# Usarei a convenção de dispensar variaveis que em mais de 15% das amostras tem seus dados perdidos
train.drop(['PoolQC','MiscFeature','Alley','Fence','FireplaceQu','LotFrontage'],axis=1,inplace=True)
test.drop(['PoolQC','MiscFeature','Alley','Fence','FireplaceQu','LotFrontage'],axis=1,inplace=True)

# %% [markdown]
# Now i will try to analyse features with missing data that have correlation with better features, so i can drop the worst one, if i find them redundant.Checking the heatmap of correlations i came to some conclusions:
# As said earlier about GarageYrBlt and YrBlt correlation, i will drop GarageYrBlt considering YrBlt  sufficient.As for others Garage related features,i will drop every one of them, except GarageCars and Garage Area, for those are suficiently correlated to support the Garage importance. But, considering the two redundant, i will just stick with GarageCars feature.

# %%
train.drop(['GarageYrBlt','GarageType','GarageFinish','GarageQual','GarageCond','GarageArea','BsmtFinType2','BsmtExposure',
'BsmtFinType1','BsmtCond','BsmtQual','BsmtFullBath','BsmtHalfBath','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF'],axis=1,inplace=True)
test.drop(['GarageYrBlt','GarageType','GarageFinish','GarageQual','GarageCond','GarageArea','BsmtFinType2','BsmtExposure',
'BsmtFinType1','BsmtCond','BsmtQual','BsmtFullBath','BsmtHalfBath','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF'],axis=1,inplace=True)

# %% [markdown]
# For all other missing data, i will apply the mean value for the quantitative features, and the mode value for the qualitative features:

# %%
print(train['MasVnrArea'].dtype)
print(train['MasVnrType'].dtype)
print(train['Electrical'].dtype)
print('\n')
print(test['MSZoning'].dtype)
print(test['GarageCars'].dtype)
print(test['KitchenQual'].dtype)
print(test['TotalBsmtSF'].dtype)
print(test['Utilities'].dtype)
print(test['Functional'].dtype)
print(test['Exterior1st'].dtype)
print(test['Exterior2nd'].dtype)
print(test['SaleType'].dtype)
# Out:
# float64
# object
# object
#
#
# object
# float64
# object
# float64
# object
# object
# object
# object
# object

# %%
for col in ('MasVnrArea','GarageCars','TotalBsmtSF'):
    train[col]=train[col].fillna(train[col].mean())
    test[col]=test[col].fillna(test[col].mean())

# %%
for col in ('MasVnrType','Electrical','KitchenQual','MSZoning','Utilities','Functional','Exterior1st','Exterior2nd','SaleType'):
    train[col]=train[col].fillna(train[col].mode()[0])
    test[col]=test[col].fillna(test[col].mode()[0])

# %%
# Checking if i didn't let any missing data behind
train.isnull().sum().max()
# Out:
# 0

# %%
test.isnull().sum().max()
# Out:
# 0

# %%
train.shape
# Out:
# (1460, 59)

# %%
test.shape
# Out:
# (1459, 58)

# %% [markdown]
# ## Outliers

# %% [markdown]
# For the outliers analysis, i will check once again the heatmap of correlations, but with only the 10 most important features for the target variable

# %%
corr= train.corr()
k = 10
col = corr.nlargest(k,'SalePrice')['SalePrice'].index
coefs = np.corrcoef(train[col].values.T)
plt.subplots(figsize=(10,7))
sb.heatmap(coefs,annot=True,xticklabels=col,yticklabels=col)

# %% [markdown]
# Now i will scatterplot the relation of those features with SalePrice and check for outliers

# %%
var = 'OverallQual'
ax = sb.scatterplot(x=train[var],y=train['SalePrice'])

# %%
var = 'GrLivArea'
ax = sb.scatterplot(x=train[var],y=train['SalePrice'])

# %% [markdown]
# Two dots here bring my attention, those who had very large GrLiveARea and relativly low price, i will consider them as outliers and drop them

# %%
train.sort_values(by = 'GrLivArea', ascending = False)[:2]
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 1298  1299          60       RL    63887   Pave      IR3         Bnk
# 523    524          60       RL    40094   Pave      IR1         Bnk
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 1298    AllPub    Corner       Gtl  ...             0         0           0
# 523     AllPub    Inside       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 1298      480       0       1    2008       New        Partial    160000
# 523         0       0      10    2007       New        Partial    184750
#
# [2 rows x 59 columns]

# %%
train = train.drop(train[train['Id'] == 1299].index)
train = train.drop(train[train['Id'] == 524].index)

# %%
train.shape
# Out:
# (1458, 59)

# %%
test.shape
# Out:
# (1459, 58)

# %%
var = 'GrLivArea'
ax = sb.scatterplot(x=train[var],y=train['SalePrice'])

# %%
var = 'GarageCars'
ax = sb.scatterplot(x=train[var],y=train['SalePrice'])

# %% [markdown]
# Those 2 dots high up there on  GarageCars = 3.0 are kind of annoying me , but don't know if it is right to consider them as outliers yet

# %%
var = 'TotalBsmtSF'
ax = sb.scatterplot(x=train[var],y=train['SalePrice'])

# %%
var = '1stFlrSF'
ax = sb.scatterplot(x=train[var],y=train['SalePrice'])

# %%
var = 'FullBath'
ax = sb.scatterplot(x=train[var],y=train['SalePrice'])

# %%
var = 'TotRmsAbvGrd'
ax = sb.scatterplot(x=train[var],y=train['SalePrice'])

# %%
var = 'YearBuilt'
ax = sb.scatterplot(x=train[var],y=train['SalePrice'])

# %%
var = 'YearRemodAdd'
ax = sb.scatterplot(x=train[var],y=train['SalePrice'])

# %% [markdown]
# Those same two dots looks like outliers and almost every of those scatterplots, so i decide to drop them

# %%
train.sort_values(by = 'SalePrice',ascending = False)[:2]
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 691    692          60       RL    21535   Pave      IR1         Lvl
# 1182  1183          60       RL    15623   Pave      IR1         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# 691     AllPub    Corner       Gtl  ...             0         0           0
# 1182    AllPub    Corner       Gtl  ...             0         0           0
#
#      PoolArea MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 691         0       0       1    2007        WD         Normal    755000
# 1182      555       0       7    2007        WD        Abnorml    745000
#
# [2 rows x 59 columns]

# %%
train = train.drop(train[train['Id'] == 692].index)
train = train.drop(train[train['Id'] == 1183].index)

# %%
# checking if i drop them right
var = 'YearRemodAdd'
ax = sb.scatterplot(x=train[var],y=train['SalePrice'])

# %%
train.shape
# Out:
# (1456, 59)

# %%
test.shape
# Out:
# (1459, 58)

# %% [markdown]
# ## Variable Transformation
#
# To apply the prediction models, all my data have to be numerical, so we will encode with get_dummies function the categorical features

# %%
train_feat = train.drop('SalePrice',axis=1) # Just want the features, droping the saleprice column
test_feat = test

trainlen = len(train_feat) # saving train length

# %%
dataset = pd.concat(objs=[train_feat,test_feat],axis=0).reset_index(drop=True) # meshing the datasets, important to keep the same columns number
dataset = pd.get_dummies(dataset) # coding categorical features to numerical

train_feat = dataset[:trainlen] # getting trainset back
test_feat = dataset[trainlen:]  # getting testset back

# %%
train_feat.shape
# Out:
# (1456, 219)

# %%
test_feat.shape
# Out:
# (1459, 219)

# %% [markdown]
# ## Modelling
#  For modelling porpuse , i will make a train_test_split, because this test dataframe we don't have the SalePrice column for competition issues, so i will create other test dataframe from the train dataset, and i will called them SUBtrain and SUBtest, just so it don't become too confusing

# %%
xtrain = train_feat 
SalePricelog = np.log(train['SalePrice']) # log transform to normalize the distribution
ytrain = SalePricelog

# %%
from sklearn.model_selection import train_test_split

subX_train,subX_test,subY_train,subY_test = train_test_split(xtrain,ytrain,test_size=0.2)

# %%
import xgboost as xgb

# %% [markdown]
# ### XGBoost Hyper Tunning Parameters

# %%
import xgboost as xgb
model = xgb.XGBRegressor() # using default parameters
model.fit(subX_train,subY_train)

print('(Sub)train accuracy: ', model.score(subX_train,subY_train))
print('(Sub)test accuracy: ', model.score(subX_test,subY_test))
# Out:
# (Sub)train accuracy:  0.9990963927335216
# (Sub)test accuracy:  0.880518740514393

# %% [markdown]
# Train accuracy is almost perfect, but doesnt fit quite well in test set, with only 88% accuracy of the test dataframe, showing us the model is probably overfit, so what i will try to tune the parameters to fix this.
#
# I will tune by this fine gentleman method here : https://www.youtube.com/watch?v=AvWfL1Us3Kg&t=1476s , in case you are interessed.

# %%
model = xgb.XGBRegressor(max_depth=4,
                         subsample=0.8,
                         n_estimators=400,
                         learning_rate=0.05,
                         min_child_weight=2,
                         colsample_bylevel=0.4,
                         
                        )
model.fit(subX_train,subY_train)

print('(Sub)train accuracy: ', model.score(subX_train,subY_train))
print('(Sub)test accuracy: ', model.score(subX_test,subY_test))
# Out:
# (Sub)train accuracy:  0.9818195813876485
# (Sub)test accuracy:  0.9015544118725193

# %% [markdown]
# Tuning the parameters i could fix a lit bit the overfit, and the test accuracy raise almost 2%.

# %%
prediction= model.predict(test_feat)
prediction = np.exp(prediction)
prediction
# Out:
# array([119850.59, 156565.73, 172717.23, ..., 142864.48, 116472.01,
#        213488.14], dtype=float32)

# %%
sample_sub = pd.read_csv(r'C:\Users\Nathan\Documents\House Prices\house-prices-advanced-regression-techniques\sample_submission.csv')
sample_sub.head()
# Out:
#      Id      SalePrice
# 0  1461  169277.052498
# 1  1462  187758.393989
# 2  1463  183583.683570
# 3  1464  179317.477511
# 4  1465  150730.079977

# %%
submission = pd.DataFrame({'Id': test.Id, 'SalePrice': prediction})
submission.to_csv('submission.csv', index=False)

# %% [markdown]
# Honestly, not quite happy with the score results, but as my first data science code ever, i'm gonna go with it for now and maybe try to approach this competition later when i get more experience
